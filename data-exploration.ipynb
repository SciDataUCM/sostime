# %% [markdown]
# # SOSTIME
#
# ## Data Exploration
#
# We will explore the datasets that we have ever considered for SOSTIME through this Jupyter Notebook in order to understand our data.
#
# If you would like to consider a dataset for SOSTIME that is not here, feel free to fork the repository and add your data exploration. We consider essential to explore every dataset before considering using it. We keep this notebook in the repository to make it easier to start developing SOSTIME.

# %%
import pandas as pd

# %% [markdown]
# ### Fire incidents

# %% [markdown]
# #### 1. [Fire statistics: Response times - data.gov.uk](https://data.gov.uk/dataset/ef8cbbd3-6857-4e45-9ce8-666a5ffb2757/fire-statistics-response-times)

# %% [markdown]
# #### 2. [Fire statistics: non-fire incidents - data.gov.uk](https://data.gov.uk/dataset/b81af0c5-6de6-4dbd-85df-ddaabee79d86/fire-statistics-non-fire-incidents)

# %% [markdown]
# ### Health incidents

# %% [markdown]
# #### 1.  [Paramedic Plus Response Time - data.acgov.org](https://data.acgov.org/Public-Safety/Paramedic-Plus-Response-Time/9yek-274s)

# %% [markdown]
# The following request will only get today's data.

# %%
h1_data = pd.read_json("https://data.acgov.org/resource/ht6t-bfmy.json")
h1_data.head()
# Out:
#      at_hospital_time       at_scene_time      available_time  \
# 0 2018-12-02 08:52:35 2018-12-02 08:23:46 2018-12-02 09:55:52
# 1 2018-12-02 11:16:07 2018-12-02 10:27:47 2018-12-02 11:51:44
# 2 2018-12-02 17:28:00 2018-12-02 17:05:29 2018-12-02 17:52:58
# 3 2018-12-02 21:21:00 2018-12-02 21:02:41 2018-12-02 21:50:00
# 4 2018-12-02 05:39:00 2018-12-02 05:18:37 2018-12-02 06:12:37
#
#             call_time       date                       diagnose  \
# 0 2018-12-02 08:10:04 2013-10-16               General Weakness
# 1 2018-12-02 10:24:42 2013-10-10        Non-Traumatic Body Pain
# 2 2018-12-02 16:59:49 2014-01-18     Chest Pain - Not Specified
# 3 2018-12-02 20:46:24 2013-12-01        Non-Traumatic Body Pain
# 4 2018-12-02 05:10:54 2014-03-15  Behavioral/Psychiatric Crisis
#
#       dispatched_time        enroute_time  \
# 0 2018-12-02 08:14:10 2018-12-02 08:14:18
# 1 2018-12-02 10:24:53 2018-12-02 10:25:12
# 2 2018-12-02 17:01:26 2018-12-02 17:01:43
# ...

# %%
len(h1_data)
# Out:
# 1000

# %%
h1_data.describe()
# Out:
#            at_hospital_time        at_scene_time       available_time  \
# count                  1000                 1000                 1000
# unique                  903                  976                  974
# top     2018-12-02 00:00:00  2018-12-02 00:00:00  2018-12-02 20:25:00
# freq                     77                   17                    2
# first   2018-12-02 00:00:00  2018-12-02 00:00:00  2018-12-02 00:01:52
# last    2018-12-02 23:57:01  2018-12-02 23:59:00  2018-12-02 23:58:56
#
#                   call_time                 date  \
# count                  1000                 1000
# unique                  991                  180
# top     2018-12-02 07:03:03  2013-12-12 00:00:00
# freq                      2                   12
# first   2018-12-02 00:00:41  2013-09-27 00:00:00
# last    2018-12-02 23:55:21  2014-03-31 00:00:00
#
#                                  diagnose      dispatched_time  \
# ...
